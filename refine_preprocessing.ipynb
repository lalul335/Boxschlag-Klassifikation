# %%
import  data_preprocessing as dp
import pandas as pd
import json

# %%
with open('json_dataset.json', 'r') as f:
    data = json.load(f)

# %%
data[1111]
# Out:
# {'label': 'Kinnhaken',
#  'count': 200,
#  'periodNS': 1983960291.6690674,
#  'raws': [{'_id': 0,
#    'timestamp': 0.0,
#    'x': -0.54083251953125,
#    'y': -0.0946044921875,
#    'z': -0.6390838623046875},
#   {'_id': 1,
#    'timestamp': 9968999.998809814,
#    'x': -0.684173583984375,
#    'y': -0.1098480224609375,
#    'z': -0.759490966796875},
#   {'_id': 2,
#    'timestamp': 19938999.99798584,
#    'x': -0.8842620849609375,
#    'y': -0.1290283203125,
#    'z': -0.8459320068359375},
#   {'_id': 3,
#    'timestamp': 29909000.00076294,
#    'x': -1.059814453125,
#    'y': -0.183135986328125,
#    'z': -0.8995819091796875},
#   {'_id': 4,
#    'timestamp': 39877999.99960327,
#    'x': -1.16741943359375,
#    'y': -0.28070068359375,
#    'z': -0.8963623046875},
#   {'_id': 5,
#    'timestamp': 49847999.99874878,
#    'x': -1.214599609375,
#    'y': -0.370269775390625,
#    'z': -0.926116943359375},
#   {'_id': 6,
#    'timestamp': 59817999.99789429,
# ...

# %%
gerade_g = dp.extract_data('data/alex_gerade.csv')
kopf_g = dp.extract_data('data/alex_kopfhaken.csv')
kinn_g = dp.extract_data('data/alex_kinnhaken.csv')
Gerrit_Ger = dp.extract_data('data/gerrit_gerade.csv')
Gerrit_Kopf = dp.extract_data('data/gerrit_kopfhaken.csv')
Gerrit_Kinn = dp.extract_data('data/gerrit_kinnhaken.csv')

# %%
dp.plot_ds(gerade_g[1000:3000], img_name='Alex_gerade', acc=False, gyr=False, rot= False, all=True)
dp.plot_ds(kopf_g[1000:3000], img_name='Alex_kopf', acc=False, gyr=False, rot= False, all=True)
dp.plot_ds(kinn_g[1000:3000], img_name='Alex_kinn', acc=False, gyr=False, rot= False, all=True)
dp.plot_ds(Gerrit_Ger[1000:3000], img_name='Gerrit_gerade', acc=False, gyr=False, rot= False, all=True)
dp.plot_ds(Gerrit_Kopf[1000:3000], img_name='Gerrit_kopf', acc=False, gyr=False, rot= False, all=True)
dp.plot_ds(Gerrit_Kinn[1000:3000], img_name='Gerrit_kinn', acc=False, gyr=False, rot= False, all=True)
